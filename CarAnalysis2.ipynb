# %% [markdown]
# ## Cars Data Analysis Using Python
# <img src='cars2.jpg' width=444>
#
# ### Importing Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read data file

# %%
df = pd.read_csv('car_data.csv')
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
#shape of the dataframe 
df.shape
# Out:
# (426, 15)

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ### 1. Find the null value

# %%
# Every columns has Null values:
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
# Information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
#Using dropna function to remove null values:
dup = df.dropna(how='any',axis=0,inplace=True)

# %% [markdown]
# ### Now all the NULL values was removed:

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.shape
# Out:
# (426, 15)

# %% [markdown]
# ### Different type of cars & count value:

# %%
a = df['Make'].value_counts()
a
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Mitsubishi       13
# Dodge            13
# Hyundai          12
# Volvo            12
# Jaguar           12
# Lexus            11
# Subaru           11
# Kia              11
# Pontiac          11
# Mazda             9
# Mercury           9
# Buick             9
# Lincoln           9
# Cadillac          8
# GMC               8
# Suzuki            8
# Infiniti          8
# Saturn            8
# Saab              7
# Porsche           7
# Acura             7
# Oldsmobile        3
# Jeep              3
# Land Rover        3
# MINI              2
# Scion             2
# Isuzu             2
# Hummer            1
# Name: Make, dtype: int64

# %%
sns.set(rc={'figure.figsize':(30,5)})
sns.countplot(x=df['Make'],data=df)
plt.show()

# %% [markdown]
# ### Data Filtering
# #### Show the all records where origin is Europe & USA

# %%
#Find the number of origins:
df['Origin'].unique()
# Out:
# array(['Asia', 'Europe', 'USA'], dtype=object)

# %%
#using (isin) function to know the exist datas
df[df['Origin'].isin(['Europe','USA'])]
# Out:
#       Make                      Model   Type  Origin DriveTrain      MSRP  \
# 7     Audi                A4 1.8T 4dr  Sedan  Europe      Front  $25,940
# 8     Audi     A41.8T convertible 2dr  Sedan  Europe      Front  $35,940
# 9     Audi                 A4 3.0 4dr  Sedan  Europe      Front  $31,840
# 10    Audi  A4 3.0 Quattro 4dr manual  Sedan  Europe        All  $33,430
# 11    Audi    A4 3.0 Quattro 4dr auto  Sedan  Europe        All  $34,480
# ..     ...                        ...    ...     ...        ...       ...
# 427  Volvo    C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo    C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo                 S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                        V40  Wagon  Europe      Front  $26,135
# 431  Volvo                       XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
sns.set(rc={'figure.figsize':(13,5)})
sns.countplot(x=df['Origin'],data=df)
plt.show()

# %% [markdown]
# ####  List  out  the   cars  weight   Less  than 4000

# %%
df[df['Weight'] < 4000]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### Which car gives more milleage

# %% [markdown]
# ####  Engine size   ( 3L)  and  Display  mean  value  of   MPG  &  High  MPG

# %%
# High Horse Power and high MPG cars
a = df[df['EngineSize'] == 3]

three = a[(a['MPG_City'] >= 33) & (a['Horsepower'] >= 235)]
three
# Out:
#       Make             Model   Type Origin DriveTrain      MSRP   Invoice  \
# 164  Honda  Accord LX V6 4dr  Sedan   Asia      Front  $23,760   $21,428
# 165  Honda  Accord EX V6 2dr  Sedan   Asia      Front  $26,960   $24,304
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 164         3.0        6.0       240.0      33.0         30.0  3349.0
# 165         3.0        6.0       240.0      33.0         30.0  3294.0
#
#      Wheelbase  Length
# 164      108.0   190.0
# 165      105.0   188.0

# %% [markdown]
# ####  Engine size   (2L & below 3L)  and  Display    High  MPG cars

# %%
b  = df[(df['EngineSize'] >= 2) & (df['EngineSize'] < 3 )]
two_car = b['MPG_City'].mean()

#High HP and MPG:
b[(b['MPG_City'] > 40) & (b['Horsepower'] > 100)]
# Out:
#       Make         Model   Type Origin DriveTrain      MSRP   Invoice  \
# 108  Dodge   Neon SE 4dr  Sedan    USA      Front  $13,670   $12,849
# 109  Dodge  Neon SXT 4dr  Sedan    USA      Front  $15,040   $14,086
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 108         2.0        4.0       132.0      41.0         36.0  2581.0
# 109         2.0        4.0       132.0      41.0         36.0  2626.0
#
#      Wheelbase  Length
# 108      105.0   174.0
# 109      105.0   174.0

# %% [markdown]
# ####  Engine size   (1L & below 2L )  and  Display  High  MPG car

# %%
c = df[(df['EngineSize'] > 1) & (df['EngineSize'] <2)]
c[(c['MPG_City'] > 50) & (c['Horsepower'] > 100)]
# Out:
#        Make                     Model    Type Origin DriveTrain      MSRP  \
# 377  Toyota  Prius 4dr (gas/electric)  Hybrid   Asia      Front  $20,510
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 377  $18,926          1.5        4.0       110.0      71.0         51.0
#
#      Weight  Wheelbase  Length
# 377  2890.0      106.0   175.0
